# %% [markdown]
# # Byte Pair Encoding

# %% [markdown]
# ## 1. Download Text Data

# %%
from core import download_text

download_text("wikimedia/wikipedia", "20231101.en", "train", 10)

# %% [markdown]
# ## 2. Load Text

# %%
from core import load_text

text_data: str = load_text()

# %% [markdown]
# ## Split Corpus into Types

# %%
from core import create_types

encoded_types = create_types(text_data)

# %% [markdown]
# ## Count Types
